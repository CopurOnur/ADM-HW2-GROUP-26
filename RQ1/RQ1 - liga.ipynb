# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

teams = pd.read_json('C:\\Users\\Gabriele\\Desktop\\datasets\\teams.json')
england = pd.read_json('C:\\Users\\Gabriele\\Desktop\\datasets\\matches_Spain.json')

# %%
for i in range(len(teams)):
    
    if teams.loc[i, 'type'] != 'club':
        teams = teams.drop(i)
        
    elif teams.loc[i, 'area']['name'] != 'Spain':
        teams = teams.drop(i)
        
teams = teams.reset_index(drop=True)   # reset indexes


points_teams = {}

for index1 in range(len(teams)):
    points_teams[teams.loc[index1, 'name']] = [0]
    
    for index2 in range(1,39): 
            
            for index3 in range(len(england)):
                if england.loc[index3, 'gameweek'] == index2:
                    
                    if ((teams.loc[index1, 'name'] in england.loc[index3, 'label']) == True):
                        if (england.loc[index3, 'winner'] == teams.loc[index1, 'wyId']):
                            points_teams[teams.loc[index1, 'name']].append(3 + points_teams[teams.loc[index1, 'name']][index2 -1])
                            
                        elif (england.loc[index3, 'winner'] == 0):
                            points_teams[teams.loc[index1, 'name']].append(1 + points_teams[teams.loc[index1, 'name']][index2 -1])
                        
                        elif (england.loc[index3, 'winner'] != teams.loc[index1, 'wyId']):
                            points_teams[teams.loc[index1, 'name']].append(points_teams[teams.loc[index1, 'name']][index2 -1])

teams
# Out:
#                                                  area  \
# 0   {'name': 'Spain', 'id': '724', 'alpha3code': '...
# 1   {'name': 'Spain', 'id': '724', 'alpha3code': '...
# 2   {'name': 'Spain', 'id': '724', 'alpha3code': '...
# 3   {'name': 'Spain', 'id': '724', 'alpha3code': '...
# 4   {'name': 'Spain', 'id': '724', 'alpha3code': '...
# 5   {'name': 'Spain', 'id': '724', 'alpha3code': '...
# 6   {'name': 'Spain', 'id': '724', 'alpha3code': '...
# 7   {'name': 'Spain', 'id': '724', 'alpha3code': '...
# 8   {'name': 'Spain', 'id': '724', 'alpha3code': '...
# 9   {'name': 'Spain', 'id': '724', 'alpha3code': '...
# 10  {'name': 'Spain', 'id': '724', 'alpha3code': '...
# 11  {'name': 'Spain', 'id': '724', 'alpha3code': '...
# 12  {'name': 'Spain', 'id': '724', 'alpha3code': '...
# 13  {'name': 'Spain', 'id': '724', 'alpha3code': '...
# 14  {'name': 'Spain', 'id': '724', 'alpha3code': '...
# 15  {'name': 'Spain', 'id': '724', 'alpha3code': '...
# 16  {'name': 'Spain', 'id': '724', 'alpha3code': '...
# 17  {'name': 'Spain', 'id': '724', 'alpha3code': '...
# 18  {'name': 'Spain', 'id': '724', 'alpha3code': '...
# 19  {'name': 'Spain', 'id': '724', 'alpha3code': '...
#
#                            city                      name  \
# 0                          Vigo             Celta de Vigo
# 1                     Barcelona                  Espanyol
# 2               Vitoria-Gasteiz     Deportivo Alav\u00e9s
# 3                      Valencia                   Levante
# 4               Getafe (Madrid)                    Getafe
# 5                        Bilbao             Athletic Club
# 6                        Madrid      Atl\u00e9tico Madrid
# 7                      Valencia                  Valencia
# 8                        Madrid               Real Madrid
# 9                     Barcelona                 Barcelona
# 10   Las Palmas de Gran Canaria                Las Palmas
# 11                 Legan\u00e9s              Legan\u00e9s
# 12                        Eibar                     Eibar
# 13                       Girona                    Girona
# 14                A Coru\u00f1a  Deportivo La Coru\u00f1a
# 15                      Sevilla                Real Betis
# 16  Donostia-San Sebasti\u00e1n             Real Sociedad
# 17                      Sevilla                   Sevilla
# 18                       Malaga               M\u00e1laga
# 19                   Villarreal                Villarreal
#
#                              officialName  type  wyId
# 0                 Real Club Celta de Vigo  club   692
# 1            Reial Club Deportiu Espanyol  club   691
# 2                   Deportivo Alav\u00e9s  club   696
# 3                              Levante UD  club   695
# 4              Getafe Club de F\u00fatbol  club   698
# 5                    Athletic Club Bilbao  club   678
# 6            Club Atl\u00e9tico de Madrid  club   679
# 7            Valencia Club de F\u00fatbol  club   674
# 8         Real Madrid Club de F\u00fatbol  club   675
# 9                            FC Barcelona  club   676
# 10                          UD Las Palmas  club   714
# 11                        CD Legan\u00e9s  club   712
# 12                               SD Eibar  club   701
# 13                              Girona FC  club   756
# 14  Real Club Deportivo de La Coru\u00f1a  club   677
# 15               Real Betis Balompi\u00e9  club   684
# 16           Real Sociedad de F\u00fatbol  club   687
# 17                             Sevilla FC  club   680
# 18        M\u00e1laga Club de F\u00fatbol  club   683
# 19         Villarreal Club de F\u00fatbol  club   682

# %%
win_max = {}
lose_max = {}

for key, value in points_teams.items():
    win_max[key] = 0
    count = 0
    for j in range(len(value)-1):
        if value[j+1] - value[j] == 3:
            count += 1
            if count > win_max[key]:
                win_max[key] = count
        else:
            count = 0
            
            
for key, value in points_teams.items():
    lose_max[key] = 0
    count = 0
    for j in range(len(value)-1):
        if value[j+1] - value[j] == 0:
            count += 1
            if count > lose_max[key]:
                lose_max[key] = count
        else:
            count = 0

# %%
list_win = []
list_lose = []

key_max1 = max(win_max.keys(), key=(lambda k: win_max[k]))
key_max2 = max(lose_max.keys(), key=(lambda k: lose_max[k]))
list_win.append(key_max1)
list_lose.append(key_max2)


del win_max[key_max1]
del lose_max[key_max2]


key_max1 = max(win_max.keys(), key=(lambda k: win_max[k]))
key_max2 = max(lose_max.keys(), key=(lambda k: lose_max[k]))
list_win.append(key_max1)
list_lose.append(key_max2)

# %%
plt.figure(figsize=(20,13))
for index4 in range(len(points_teams)): 
    
    if teams.loc[index4, 'name'] in list_win:
        plt.plot(points_teams[teams.loc[index4, 'name']], linewidth=4 ,label = teams.loc[index4, 'name']) 
        
    elif teams.loc[index4, 'name'] in list_lose:
        plt.plot(points_teams[teams.loc[index4, 'name']],'--', linewidth=3, label = teams.loc[index4, 'name'])
    
    else:
        plt.plot(points_teams[teams.loc[index4, 'name']], label = teams.loc[index4, 'name']) 
        
plt.xlabel('weeks')  
plt.ylabel('points')
plt.legend()
plt.show()
